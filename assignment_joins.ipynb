# %% [markdown]
# ANSWER1:
# SELECT c.CustomerID
# FROM Customers c
#  JOIN Orders o
# on  c.CustomerID = o.CustomerID;
#
#
#
#
# **Second method**:select CustomerID
# from  customers where CustomerID in (select  CustomerID
#  from orders);

# %% [markdown]
# ANSWER2:
# SELECT *
# FROM Customers c
#  LEFT JOIN Orders o
#  on  c.CustomerID = o.CustomerID;

# %% [markdown]
# ANSWER3: SELECT *
# FROM Customers c
#  right JOIN Orders o
#
# on  c.CustomerID = o.CustomerID;
#
# ANSWER4:
# SELECT c.CustomerName, o.OrderID
# FROM customers c
# LEFT JOIN orders o  ON c.CustomerID= o.customerID
#
# UNION
#
# SELECT c.CustomerName, o.orderID
# FROM customers c
# RIGHT JOIN orders o
#  ON c.customerID = o.CustomerID;
#
# ANSWER5:
# select c.customerID,o.CustomerID
# from customers c
# left join orders o
# on c.CustomerID=o.CustomerID
# where o.customerID IS NULL;
#
# ANOTHER METHOD: select CustomerID from Customers where CustomerID  not in (select CustomerID from orders);

# %% [markdown]
# ANSWER6:
# SELECT c.CustomerID
# FROM Customers c
# INNER JOIN Payments p
#     ON c.CustomerID = p.CustomerID
#
# LEFT JOIN Orders o
#     ON c.CustomerID = o.CustomerID
# WHERE o.CustomerID IS NULL;
#
# ANSWER7:
#
# select c.customerID,o.OrderID
# from customers as c
# cross join
# orders as o;
#
# ANSWER8:
#
# SELECT c.CustomerID,o.OrderID,o.Amount,p.Amount
#
#     from customers c
# LEFT JOIN orders o
# ON c.CustomerID = o.CustomerID
#
# LEFT JOIN payments p
# ON c.CustomerID = p.CustomerID;
#
# ANSWER9:
#
# SELECT c.CustomerID
# FROM Customers c
#  JOIN Orders o
# on  c.CustomerID = o.CustomerID;
# LEFT join payments p on c.customerID = p.CustomerID;
