# %% [markdown]
# ASSIGNMENT: FILTERING AND SORTING
# **bold text**

# %% [markdown]
# QUESTION1:
# ANSWER1:  select EmpName from employees where department='IT' or department='HR';
#
# Answer2: select EmpName from employees where department in('sales','IT','HR');
#
# ANSWER3:select EmpName from employees where Salary between 50000 and 70000;
#
#
# Answer4:select EmpName from employees where EmpName like'A%';
#
# Answer5: select EmpName from employees where EmpName like'%an%';
#
# Answer6:select EmpName from employees where  (city='Delhi' or city='Mumbai') and Salary > 55000;
#
#
# Answer7:select EmpName from employees where department != 'HR';
#
# Answer8: select EmpName from employees where year(HireDate) between 2019 and 2022 order by HireDate asc;
