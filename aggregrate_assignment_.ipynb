# %%
AGGREGRATION ASSIGNMENT SOLUTION

# %% [markdown]
# ANSWER1:  SELECT
#     CountryCode,
#
#     COUNT(Name) AS TotalCities
# FROM
#    city
#
# GROUP BY
#     CountryCode;
#
#     **********************************
#
#     ANSWER2:
#
#     SELECT  continent,count(*) as  totalcontries
# from  country
#
# GROUP BY
#     continent having totalcontries>30;
#
#     ******************************************************

# %% [markdown]
# ANSER3:
# select region,sum(Population) as totalpopulation
# from country
#
# group by region
#
# having totalpopulation>20000000;
# **********************************
# ANSWER4:
# ELECT Continent,
# AVG(GNP) AS Average_GNP
# FROM country
#
# GROUP BY Continent
#
# ORDER BY Average_GNP DESC
# LIMIT 5;
# *****************************************************
# ANSWER5:
#
# SELECT
#     c.Continent,
#     COUNT(cl.Language) AS Total_Official_Languages,
#
#     cl.IsOfficial
#
# FROM
#     country c
#
# JOIN
#     countrylanguage cl
#
#     ON c.Code = cl.CountryCode
#
# WHERE
#     cl.IsOfficial = 'T'
#
# GROUP BY
#     c.Continent;
#
#   *********************************
#
#   ANSWER6:
#
#   select max(GNP) as max_GNP ,
#      min(GNP) as min_GNP,
#      continent
#      FROM  COUNTRY
#      group by continent;
#
#      ***************************************
#
#
# ANSWER7:
#
# SELECT
# Name,
# avg(Population) as averg_city_pop
# FROM country
#
# GROUP BY Name
#
# order by averg_city_pop desc limit 1;
#
#
# ***********************************************
#
# ANSWER8:
#
#
# SELECT country.Continent,
#
#  AVG(city.Population) AS Average_City_Population
#
# FROM city
#
# JOIN country
# ON city.CountryCode = country.Code
#
# GROUP BY country.Continent
#
# HAVING AVG(city.Population) > 200000;
#
# ********************************************

# %% [markdown]
# ANSWER9:
#
# select continent,
# sum(Population) as total_population,
# avg(LifeExpectancy) as ave_lfex
# from country
#
# group by continent
#
# order by ave_lfex desc;
#
# **********************************************************
# ANSWER10:
#
# select continent,
# sum(Population) as total_population,
# avg(LifeExpectancy) as ave_lfex
#
# from country
#  group by continent having total_population>200000000
#
# order by ave_lfex desc limit 3;
#
#
# *************************************END******************************************
