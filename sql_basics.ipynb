# %% [markdown]
# create table if not exists employees (
# employee_id INT  not null primary key,
# first_name VARCHAR(50),
# last_name VARCHAR(50),
# department VARCHAR(50),
# hire_date date,
# salary INT
# );

# %% [markdown]
# question 1
# answer:
# create database company_db;
# use company_db;employees
#
# create table if not exists employees (
# employee_id INT  not null primary key,
# first_name VARCHAR(50),
# last_name VARCHAR(50),
# department VARCHAR(50),
# hire_date date,
# salary INT
# );

# %% [markdown]
# # sql basics

# %% [markdown]
# anwer1

# %%
create database company_db;
use company_db;employees

create table if not exists employees (
employee_id INT  not null primary key,
first_name VARCHAR(50),
last_name VARCHAR(50),
department VARCHAR(50),
hire_date date,
salary INT
);

# %% [markdown]
# ANSWER 2:

# %%
insert into employees
values(101,'amit','sharma','HR','22020-01-15',50000);
insert into employees
insert into employees
values(102,'riya','kapoor','sales','2019-03-22',75000);
insert into employees
values(103,'raj','mehta','it','2018-07-11',900000);
insert into employees
values(104,'neha','verma','it','2021-09-01',85000);
insert into employees
values(105,'arjun','singh','finance','2022-02-10',60000);

 insert into sales
values(1,'Aditi',1500,'2024-08-01');

insert into sales
values(2,'Rohan',2200,'2024-08-03');
insert into sales
values(3,'Aditi',3500,'2024-09-05');
insert into sales
values(4,'Meena',2700,'2024-09-15');
insert into sales
values(5,'Rohan',4500,'2024-09-25');
select * from sales;

# %% [markdown]
# ANSWER8:

# %%
select * from sales where customer_name='Aditi';

# %% [markdown]
# **ANSWER7:**

# %%
select * from sales order by amount desc;

# %% [markdown]
# ANSWER3:

# %%
select * from employees order by salary asc;

# %% [markdown]
# **ANSWER9:**

# %%
A  primary key uniquely  defines each record in a table, it doesn't allow duplicates or null values to enter.and sometimes acts as a relational link between two tables.
a foreign key is  a column in a relattional database table that creates link  between  data in two tables.it generally refers the primary key of other tablehencw creating a child parent relationship.

# %% [markdown]
# answer10:

# %%
contraints are the rules applied on data column  for data integrity, accuracy and relaibility, it act as a preventing layer  that prevents  to enter in adequate  data to be in serted  and ensurinf the database  meets thespecific bussiness needs.

# %% [markdown]
# ANSWER4:

# %% [markdown]
# select * from employees order by department asc,salary desc;

# %% [markdown]
# ANSER5:

# %%
select first_name,hire_date,department from employees where department='IT'order by hire_date desc;

# %% [markdown]
# **ANSWER6:**

# %%
create table if not exists sales (
sale_id   int primary key,
customer_name  VARCHAR(50) ,
 amount INT,
 sale_date date);

 insert into sales
values(1,'Aditi',1500,'2024-08-01');

insert into sales
values(2,'Rohan',2200,'2024-08-03');
insert into sales
values(3,'Aditi',3500,'2024-09-05');
insert into sales
values(4,'Meena',2700,'2024-09-15');
insert into sales
values(5,'Rohan',4500,'2024-09-25');
